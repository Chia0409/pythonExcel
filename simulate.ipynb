# %%
import pandas as pd
import numpy as np

# %%
imput_file = "simulate.xlsx"
output_file = "simulate_output.xlsx"
target_sheet = "fact_reimbursements"

excel_file = pd.ExcelFile(imput_file)
if target_sheet in excel_file.sheet_names:
    factReim_df = pd.read_excel(excel_file, sheet_name = target_sheet)
factReim_df
# Out:
#      reimburse_id     po_date to_finance_date     gl_date applicant_id  \
# 0               1  2025-11-24      2025-11-27  2025-11-28       EMP024
# 1               2  2025-11-29      2025-12-09  2025-12-13       EMP008
# 2               3  2025-02-19      2025-02-26  2025-03-01       EMP020
# 3               4  2025-04-09      2025-04-12  2025-04-13       EMP022
# 4               5  2025-04-18      2025-04-24  2025-04-25       EMP020
# ..            ...         ...             ...         ...          ...
# 145           146  2025-08-30      2025-09-01  2025-09-04       EMP014
# 146           147  2025-12-05      2025-12-15  2025-12-17       EMP021
# 147           148  2025-08-06      2025-08-16  2025-08-20       EMP027
# 148           149  2025-02-04      2025-02-07  2025-02-12       EMP002
# 149           150  2025-09-15      2025-09-21  2025-09-23       EMP027
#
#      vendor_id    project_no        po_no   invoice_no  gl_code capex_expense  \
# ...
